# %% [markdown]
# <a href="https://colab.research.google.com/github/j0z3ph/proyecto_prueba/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Esto es mi primer programa en Python!!**
#
# ---

# %%
print('hola')
# Out:
# hola

# %%
print('hola')
print('HOLAAAAAAAAA')
# Out:
# hola
# HOLAAAAAAAAA

# %% [markdown]
# Documentacion

# %%
a = input("Ingresa algo: ")
print(a)
# Out:
# Ingresa algo: hola
# hola

# %%
# !pwd
# Out:
# /content

# %%
# %%writefile saludo.py

def saludar(nombre):
    return f"Hola, {nombre}!"
# Out:
# Writing saludo.py

# %%
import saludo as s
s.saludar('jose')
# Out:
# 'Hola, jose!'

# %%
import numpy as np
a = np.array([1,2,3])
for e in a:
  print(f'Num: {e}')
# Out:
# Num: 1
# Num: 2
# Num: 3

# %%
# !uname -a
# !cat /etc/os-release
# Out:
# Linux 23832f9b4b08 6.6.122+ #1 SMP Thu Apr 30 18:17:14 UTC 2026 x86_64 x86_64 x86_64 GNU/Linux
# PRETTY_NAME="Ubuntu 22.04.5 LTS"
# NAME="Ubuntu"
# VERSION_ID="22.04"
# VERSION="22.04.5 LTS (Jammy Jellyfish)"
# VERSION_CODENAME=jammy
# ID=ubuntu
# ID_LIKE=debian
# HOME_URL="https://www.ubuntu.com/"
# SUPPORT_URL="https://help.ubuntu.com/"
# BUG_REPORT_URL="https://bugs.launchpad.net/ubuntu/"
# PRIVACY_POLICY_URL="https://www.ubuntu.com/legal/terms-and-policies/privacy-policy"
# UBUNTU_CODENAME=jammy
